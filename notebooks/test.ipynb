# %% [markdown]
# <a href="https://colab.research.google.com/github/Roms-tripleten/git-practice-colaborative/blob/main/notebooks/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Text")
# Out:
# Text
